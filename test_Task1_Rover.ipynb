# %%
'''
    Student shall write their names here
        1. Hoang Luu
        2. Lucas Svensson Zettel
'''

# %%
# !ls
# %cd TDD
import Task1_Rover
import importlib
# Out:
# __pycache__  Task1_Rover.py  test_Task1_Rover.ipynb
# README.md    TDD.ipynb	     test_Task1_Rover.py
# [Errno 2] No such file or directory: 'TDD'
# /content/TDD

# %%
import unittest
import pytest
importlib.reload(Task1_Rover)
from Task1_Rover import rovar

# %%
class test_string(unittest.TestCase):
    '''
        _LOWER_CONSTANTS = "bcdfhjklmnpqrstvwxz"
        _UPPER_CONSTANTS = "BCFGHJKLMNPQRSTVWXZ"
        Swedish vowels = ['a', 'e', 'i', 'o', 'u', 'y', 'å', 'ä', 'ö']

        Write your TCs based on the lab instructions. One TC has been written below as an example

    '''

    def setUp(self):
        '''
            Set up shared resources = Class instance to access rover class methods
        '''
        self.rv = rovar()

    # Example test case to check lower case rover fafasfdafasffasfas
    def test_enrove_small(self):
       self.assertEqual(self.rv.enrove('b'), 'bob')

    # You can continue writing your test cases here based on the assignment description
    def test_null_input_enrove(self):
       with self.assertRaises((TypeError, ValueError)):
            self.rv.enrove(None)

# %%
if __name__ == '__main__':
    print("***********START OF All TEST CASES RESULTS SHOWN BELOW**************")
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_enrove_small (__main__.test_string.test_enrove_small) ... ok
# test_null_input_enrove (__main__.test_string.test_null_input_enrove) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK
# ***********START OF All TEST CASES RESULTS SHOWN BELOW**************

# %%
# !jupyter nbconvert --to script /content/TDD/test_Task11_Rover.ipynb --output test_Task1_Rover.py
# Out:
# [NbConvertApp] Converting notebook /content/TDD/test_Task11_Rover.ipynb to script
# [NbConvertApp] Writing 999 bytes to /content/TDD/test_Task1_Rover.py.txt

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	__pycache__/
# 	test_Task1_Rover.py.txt
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add Task1_Rover.py
# !git add test_Task1_Rover.ipynb

# %%
# !git commit -m "test"
# Out:
# [main 691137b] test
#  1 file changed, 159 insertions(+), 258 deletions(-)
#  rewrite test_Task1_Rover.ipynb (98%)

# %%
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 889 bytes | 889.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/aswx12/TDD.git
#    352dcd3..691137b  main -> main
